# %%
# !conda create --name my_env netcdf4 -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ap18525\.conda\envs\my_env
#
#   added / updated specs:
#     - netcdf4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       hfa6e2cd_1         148 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         181 KB  conda-forge
#     certifi-2019.6.16          |           py37_1         149 KB  conda-forge
#     cftime-1.0.3.4             |py37h452e1ab_1001         218 KB  conda-forge
#     hdf5-1.10.5                |nompi_ha405e13_1103        35.1 MB  conda-forge
#     libnetcdf-4.6.2            |    h376842a_1003         654 KB  conda-forge
#     netcdf4-1.5.1.2            |   py37h8c66456_1         388 KB  conda-forge
#     numpy-1.17.1               |   py37hc71023c_0         4.7 MB  conda-forge
#     pip-19.2.3                 |           py37_0         1.9 MB  conda-forge
#     python-3.7.3               |       h510b542_1        17.7 MB  conda-forge
#     setuptools-41.2.0          |           py37_0         652 KB  conda-forge
#     sqlite-3.29.0              |       hfa6e2cd_1         1.1 MB  conda-forge
#     tk-8.6.9                   |    hfa6e2cd_1003         3.7 MB  conda-forge
#     vs2015_runtime-14.16.27012 |       hf0eaf9b_0         2.4 MB
#     wheel-0.33.6               |           py37_0          52 KB  conda-forge
#     wincertstore-0.2           |        py37_1002          13 KB  conda-forge
#     zlib-1.2.11                |    h2fa13f4_1006         236 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        69.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/win-64::bzip2-1.0.8-hfa6e2cd_1
#   ca-certificates    conda-forge/win-64::ca-certificates-2019.9.11-hecc5488_0
#   certifi            conda-forge/win-64::certifi-2019.6.16-py37_1
#   cftime             conda-forge/win-64::cftime-1.0.3.4-py37h452e1ab_1001
#   curl               conda-forge/win-64::curl-7.65.3-h4496350_0
#   hdf4               conda-forge/win-64::hdf4-4.2.13-hf8e6fe8_1002
#   hdf5               conda-forge/win-64::hdf5-1.10.5-nompi_ha405e13_1103
#   intel-openmp       pkgs/main/win-64::intel-openmp-2019.4-245
#   jpeg               conda-forge/win-64::jpeg-9c-hfa6e2cd_1001
#   krb5               conda-forge/win-64::krb5-1.16.3-hdd46e55_1001
#   libblas            conda-forge/win-64::libblas-3.8.0-12_mkl
#   libcblas           conda-forge/win-64::libcblas-3.8.0-12_mkl
#   libcurl            conda-forge/win-64::libcurl-7.65.3-h4496350_0
#   liblapack          conda-forge/win-64::liblapack-3.8.0-12_mkl
#   libnetcdf          conda-forge/win-64::libnetcdf-4.6.2-h376842a_1003
#   libssh2            conda-forge/win-64::libssh2-1.8.2-h642c060_2
#   mkl                pkgs/main/win-64::mkl-2019.4-245
#   netcdf4            conda-forge/win-64::netcdf4-1.5.1.2-py37h8c66456_1
#   numpy              conda-forge/win-64::numpy-1.17.1-py37hc71023c_0
#   openssl            conda-forge/win-64::openssl-1.1.1c-hfa6e2cd_0
#   pip                conda-forge/win-64::pip-19.2.3-py37_0
#   python             conda-forge/win-64::python-3.7.3-h510b542_1
#   setuptools         conda-forge/win-64::setuptools-41.2.0-py37_0
#   sqlite             conda-forge/win-64::sqlite-3.29.0-hfa6e2cd_1
#   tk                 conda-forge/win-64::tk-8.6.9-hfa6e2cd_1003
#   vc                 pkgs/main/win-64::vc-14.1-h0510ff6_4
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.16.27012-hf0eaf9b_0
#   wheel              conda-forge/win-64::wheel-0.33.6-py37_0
#   wincertstore       conda-forge/win-64::wincertstore-0.2-py37_1002
#   zlib               conda-forge/win-64::zlib-1.2.11-h2fa13f4_1006
#
#
#
# Downloading and Extracting Packages
#
# pip-19.2.3           | 1.9 MB    |            |   0%
# pip-19.2.3           | 1.9 MB    | ########## | 100%
#
# wheel-0.33.6         | 52 KB     |            |   0%
# wheel-0.33.6         | 52 KB     | ########## | 100%
#
# zlib-1.2.11          | 236 KB    |            |   0%
# zlib-1.2.11          | 236 KB    | ########## | 100%
#
# vs2015_runtime-14.16 | 2.4 MB    |            |   0%
# vs2015_runtime-14.16 | 2.4 MB    | ######3    |  64%
# vs2015_runtime-14.16 | 2.4 MB    | ########## | 100%
#
# libnetcdf-4.6.2      | 654 KB    |            |   0%
# libnetcdf-4.6.2      | 654 KB    | ########## | 100%
#
# hdf5-1.10.5          | 35.1 MB   |            |   0%
# hdf5-1.10.5          | 35.1 MB   | #8         |  18%
# hdf5-1.10.5          | 35.1 MB   | ####3      |  43%
# hdf5-1.10.5          | 35.1 MB   | #######2   |  72%
# hdf5-1.10.5          | 35.1 MB   | ########## | 100%
#
# wincertstore-0.2     | 13 KB     |            |   0%
# wincertstore-0.2     | 13 KB     | ########## | 100%
#
# certifi-2019.6.16    | 149 KB    |            |   0%
# certifi-2019.6.16    | 149 KB    | ########## | 100%
#
# cftime-1.0.3.4       | 218 KB    |            |   0%
# cftime-1.0.3.4       | 218 KB    | ########## | 100%
#
# sqlite-3.29.0        | 1.1 MB    |            |   0%
# sqlite-3.29.0        | 1.1 MB    | ########## | 100%
#
# bzip2-1.0.8          | 148 KB    |            |   0%
# bzip2-1.0.8          | 148 KB    | ########## | 100%
#
# netcdf4-1.5.1.2      | 388 KB    |            |   0%
# netcdf4-1.5.1.2      | 388 KB    | ########## | 100%
#
# ca-certificates-2019 | 181 KB    |            |   0%
# ca-certificates-2019 | 181 KB    | ########## | 100%
#
# numpy-1.17.1         | 4.7 MB    |            |   0%
# numpy-1.17.1         | 4.7 MB    | ########6  |  87%
# numpy-1.17.1         | 4.7 MB    | ########## | 100%
#
# tk-8.6.9             | 3.7 MB    |            |   0%
# tk-8.6.9             | 3.7 MB    | ########## | 100%
#
# python-3.7.3         | 17.7 MB   |            |   0%
# python-3.7.3         | 17.7 MB   | ###1       |  31%
# python-3.7.3         | 17.7 MB   | ######5    |  66%
# python-3.7.3         | 17.7 MB   | #########9 | 100%
# python-3.7.3         | 17.7 MB   | ########## | 100%
#
# setuptools-41.2.0    | 652 KB    |            |   0%
# setuptools-41.2.0    | 652 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate my_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base conda

# %%
# !conda activate my_env

# %%
from netCDF4 import date2num

# %%
# !conda env create -f environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# pyyaml-3.12          | 132 KB    |            |   0%
# pyyaml-3.12          | 132 KB    | #2         |  12%
# pyyaml-3.12          | 132 KB    | ########## | 100%
#
# backports-1.0        | 3 KB      |            |   0%
# backports-1.0        | 3 KB      | ########## | 100%
#
# markupsafe-1.0       | 27 KB     |            |   0%
# markupsafe-1.0       | 27 KB     | ########## | 100%
#
# pip-19.2.3           | 1.9 MB    |            |   0%
# pip-19.2.3           | 1.9 MB    | ########## | 100%
#
# flask-cors-3.0.4     | 21 KB     |            |   0%
# flask-cors-3.0.4     | 21 KB     | #######5   |  76%
# flask-cors-3.0.4     | 21 KB     | ########## | 100%
#
# wheel-0.31.1         | 81 KB     |            |   0%
# wheel-0.31.1         | 81 KB     | #9         |  20%
# wheel-0.31.1         | 81 KB     | ########## | 100%
#
# pylint-1.8.4         | 787 KB    |            |   0%
# pylint-1.8.4         | 787 KB    | 2          |   2%
# pylint-1.8.4         | 787 KB    | ########## | 100%
#
# vc-14.1              | 6 KB      |            |   0%
# vc-14.1              | 6 KB      | ########## | 100%
#
# conda-package-handli | 279 KB    |            |   0%
# conda-package-handli | 279 KB    | 5          |   6%
# conda-package-handli | 279 KB    | ########## | 100%
#
# pyparsing-2.2.0      | 96 KB     |            |   0%
# pyparsing-2.2.0      | 96 KB     | #6         |  17%
# pyparsing-2.2.0      | 96 KB     | ########## | 100%
#
# xlwt-1.3.0           | 163 KB    |            |   0%
# xlwt-1.3.0           | 163 KB    | ########## | 100%
#
# icu-58.2             | 21.9 MB   |            |   0%
# icu-58.2             | 21.9 MB   | ##8        |  29%
# icu-58.2             | 21.9 MB   | ########   |  80%
# icu-58.2             | 21.9 MB   | ########## | 100%
#
# beautifulsoup4-4.6.0 | 133 KB    |            |   0%
# beautifulsoup4-4.6.0 | 133 KB    | ########## | 100%
#
# backports.shutil_get | 8 KB      |            |   0%
# backports.shutil_get | 8 KB      | ########## | 100%
#
# prompt_toolkit-1.0.1 | 338 KB    |            |   0%
# prompt_toolkit-1.0.1 | 338 KB    | 4          |   5%
# prompt_toolkit-1.0.1 | 338 KB    | ########## | 100%
#
# xlrd-1.1.0           | 194 KB    |            |   0%
# xlrd-1.1.0           | 194 KB    | 8          |   8%
# xlrd-1.1.0           | 194 KB    | ########## | 100%
#
# lzo-2.10             | 154 KB    |            |   0%
# lzo-2.10             | 154 KB    | ########## | 100%
#
# mkl-2018.0.2         | 176.6 MB  |            |   0%
# mkl-2018.0.2         | 176.6 MB  |            |   0%
# mkl-2018.0.2         | 176.6 MB  |            |   0%
# mkl-2018.0.2         | 176.6 MB  |            |   1%
# mkl-2018.0.2         | 176.6 MB  | 2          |   2%
# mkl-2018.0.2         | 176.6 MB  | 4          |   4%
# mkl-2018.0.2         | 176.6 MB  | 5          |   5%
# mkl-2018.0.2         | 176.6 MB  | 6          |   7%
# mkl-2018.0.2         | 176.6 MB  | 8          |   9%
# mkl-2018.0.2         | 176.6 MB  | 9          |  10%
# mkl-2018.0.2         | 176.6 MB  | #1         |  11%
# mkl-2018.0.2         | 176.6 MB  | #2         |  13%
# mkl-2018.0.2         | 176.6 MB  | #4         |  14%
# mkl-2018.0.2         | 176.6 MB  | #5         |  16%
# mkl-2018.0.2         | 176.6 MB  | #7         |  17%
# mkl-2018.0.2         | 176.6 MB  | #8         |  19%
# mkl-2018.0.2         | 176.6 MB  | ##         |  21%
# mkl-2018.0.2         | 176.6 MB  | ##2        |  22%
# mkl-2018.0.2         | 176.6 MB  | ##3        |  24%
# mkl-2018.0.2         | 176.6 MB  | ##5        |  25%
# mkl-2018.0.2         | 176.6 MB  | ##6        |  27%
# mkl-2018.0.2         | 176.6 MB  | ##8        |  28%
# mkl-2018.0.2         | 176.6 MB  | ##9        |  30%
# mkl-2018.0.2         | 176.6 MB  | ###1       |  31%
# mkl-2018.0.2         | 176.6 MB  | ###2       |  33%
# mkl-2018.0.2         | 176.6 MB  | ###4       |  34%
# mkl-2018.0.2         | 176.6 MB  | ###5       |  36%
# mkl-2018.0.2         | 176.6 MB  | ###7       |  37%
# mkl-2018.0.2         | 176.6 MB  | ###8       |  39%
# mkl-2018.0.2         | 176.6 MB  | ####       |  40%
# mkl-2018.0.2         | 176.6 MB  | ####1      |  42%
# mkl-2018.0.2         | 176.6 MB  | ####3      |  43%
# mkl-2018.0.2         | 176.6 MB  | ####5      |  45%
# mkl-2018.0.2         | 176.6 MB  | ####6      |  47%
# mkl-2018.0.2         | 176.6 MB  | ####8      |  48%
# mkl-2018.0.2         | 176.6 MB  | ####9      |  49%
# mkl-2018.0.2         | 176.6 MB  | #####      |  51%
# mkl-2018.0.2         | 176.6 MB  | #####2     |  52%
# mkl-2018.0.2         | 176.6 MB  | #####3     |  54%
# mkl-2018.0.2         | 176.6 MB  | #####5     |  56%
# mkl-2018.0.2         | 176.6 MB  | #####7     |  57%
# mkl-2018.0.2         | 176.6 MB  | #####8     |  59%
# mkl-2018.0.2         | 176.6 MB  | ######     |  60%
# mkl-2018.0.2         | 176.6 MB  | ######1    |  62%
# mkl-2018.0.2         | 176.6 MB  | ######3    |  63%
# mkl-2018.0.2         | 176.6 MB  | ######4    |  65%
# mkl-2018.0.2         | 176.6 MB  | ######6    |  66%
# mkl-2018.0.2         | 176.6 MB  | ######7    |  68%
# mkl-2018.0.2         | 176.6 MB  | ######9    |  69%
# mkl-2018.0.2         | 176.6 MB  | #######    |  71%
# mkl-2018.0.2         | 176.6 MB  | #######2   |  72%
# mkl-2018.0.2         | 176.6 MB  | #######4   |  74%
# mkl-2018.0.2         | 176.6 MB  | #######5   |  76%
# mkl-2018.0.2         | 176.6 MB  | #######7   |  77%
# mkl-2018.0.2         | 176.6 MB  | #######8   |  79%
# mkl-2018.0.2         | 176.6 MB  | ########   |  80%
# mkl-2018.0.2         | 176.6 MB  | ########2  |  82%
# mkl-2018.0.2         | 176.6 MB  | ########3  |  84%
# mkl-2018.0.2         | 176.6 MB  | ########5  |  85%
# mkl-2018.0.2         | 176.6 MB  | ########7  |  88%
# mkl-2018.0.2         | 176.6 MB  | ########9  |  89%
# mkl-2018.0.2         | 176.6 MB  | #########1 |  91%
# mkl-2018.0.2         | 176.6 MB  | #########2 |  93%
# mkl-2018.0.2         | 176.6 MB  | #########4 |  94%
# mkl-2018.0.2         | 176.6 MB  | #########5 |  96%
# mkl-2018.0.2         | 176.6 MB  | #########7 |  98%
# mkl-2018.0.2         | 176.6 MB  | #########9 |  99%
# mkl-2018.0.2         | 176.6 MB  | ########## | 100%
#
# patsy-0.5.0          | 323 KB    |            |   0%
# patsy-0.5.0          | 323 KB    | ########## | 100%
#
# backcall-0.1.0       | 20 KB     |            |   0%
# backcall-0.1.0       | 20 KB     | ########## | 100%
#
# html5lib-1.0.1       | 182 KB    |            |   0%
# html5lib-1.0.1       | 182 KB    | 8          |   9%
# html5lib-1.0.1       | 182 KB    | ########## | 100%
#
# anaconda-navigator-1 | 4.7 MB    |            |   0%
# anaconda-navigator-1 | 4.7 MB    | ########## | 100%
#
# libxml2-2.9.8        | 3.2 MB    |            |   0%
# libxml2-2.9.8        | 3.2 MB    | ########## | 100%
#
# entrypoints-0.2.3    | 9 KB      |            |   0%
# entrypoints-0.2.3    | 9 KB      | ########## | 100%
#
# wrapt-1.10.11        | 44 KB     |            |   0%
# wrapt-1.10.11        | 44 KB     | ########## | 100%
#
# packaging-17.1       | 33 KB     |            |   0%
# packaging-17.1       | 33 KB     | ####7      |  48%
# packaging-17.1       | 33 KB     | ########## | 100%
#
# numpydoc-0.8.0       | 43 KB     |            |   0%
# numpydoc-0.8.0       | 43 KB     | ###7       |  37%
# numpydoc-0.8.0       | 43 KB     | ########## | 100%
#
# winpty-0.4.3         | 1.1 MB    |            |   0%
# winpty-0.4.3         | 1.1 MB    | #####9     |  60%
# winpty-0.4.3         | 1.1 MB    | ########## | 100%
#
# pytz-2018.4          | 214 KB    |            |   0%
# pytz-2018.4          | 214 KB    | 7          |   7%
# pytz-2018.4          | 214 KB    | ########## | 100%
#
# cloudpickle-0.5.3    | 26 KB     |            |   0%
# cloudpickle-0.5.3    | 26 KB     | ######1    |  62%
# cloudpickle-0.5.3    | 26 KB     | ########## | 100%
#
# pywin32-223          | 9.3 MB    |            |   0%
# pywin32-223          | 9.3 MB    | ####       |  40%
# pywin32-223          | 9.3 MB    | #########2 |  93%
# pywin32-223          | 9.3 MB    | ########## | 100%
#
# comtypes-1.1.4       | 234 KB    |            |   0%
# comtypes-1.1.4       | 234 KB    | 6          |   7%
# comtypes-1.1.4       | 234 KB    | ########## | 100%
#
# imageio-2.3.0        | 3.3 MB    |            |   0%
# imageio-2.3.0        | 3.3 MB    |            |   0%
# imageio-2.3.0        | 3.3 MB    | 5          |   6%
# imageio-2.3.0        | 3.3 MB    | #          |  11%
# imageio-2.3.0        | 3.3 MB    | #6         |  17%
# imageio-2.3.0        | 3.3 MB    | ##3        |  23%
# imageio-2.3.0        | 3.3 MB    | ##9        |  29%
# imageio-2.3.0        | 3.3 MB    | ###3       |  34%
# imageio-2.3.0        | 3.3 MB    | ####1      |  42%
# imageio-2.3.0        | 3.3 MB    | ####9      |  50%
# imageio-2.3.0        | 3.3 MB    | ######     |  61%
# imageio-2.3.0        | 3.3 MB    | #######3   |  73%
# imageio-2.3.0        | 3.3 MB    | ########8  |  89%
# imageio-2.3.0        | 3.3 MB    | ########## | 100%
#
# colorama-0.3.9       | 23 KB     |            |   0%
# colorama-0.3.9       | 23 KB     | ########## | 100%
#
# pkginfo-1.4.2        | 57 KB     |            |   0%
# pkginfo-1.4.2        | 57 KB     | ##8        |  28%
# pkginfo-1.4.2        | 57 KB     | ########## | 100%
#
# pyqt-5.9.2           | 4.6 MB    |            |   0%
# pyqt-5.9.2           | 4.6 MB    |            |   0%
# pyqt-5.9.2           | 4.6 MB    | 3          |   3%
# pyqt-5.9.2           | 4.6 MB    | #4         |  15%
# pyqt-5.9.2           | 4.6 MB    | #####8     |  58%
# pyqt-5.9.2           | 4.6 MB    | ########## | 100%
#
# jpeg-9b              | 313 KB    |            |   0%
# jpeg-9b              | 313 KB    | ########## | 100%
#
# odo-0.5.1            | 213 KB    |            |   0%
# odo-0.5.1            | 213 KB    | ########## | 100%
#
# jdcal-1.4            | 12 KB     |            |   0%
# jdcal-1.4            | 12 KB     | ########## | 100%
#
# itsdangerous-0.24    | 21 KB     |            |   0%
# itsdangerous-0.24    | 21 KB     | #######7   |  78%
# itsdangerous-0.24    | 21 KB     | ########## | 100%
#
# console_shortcut-0.1 | 60 KB     |            |   0%
# console_shortcut-0.1 | 60 KB     | ########## | 100%
#
# libiconv-1.15        | 664 KB    |            |   0%
# libiconv-1.15        | 664 KB    | ########## | 100%
#
# llvmlite-0.23.1      | 9.3 MB    |            |   0%
# llvmlite-0.23.1      | 9.3 MB    |            |   0%
# llvmlite-0.23.1      | 9.3 MB    | ##9        |  30%
# llvmlite-0.23.1      | 9.3 MB    | #####2     |  53%
# llvmlite-0.23.1      | 9.3 MB    | #######9   |  79%
# llvmlite-0.23.1      | 9.3 MB    | ########## | 100%
#
# conda-verify-2.0.0   | 38 KB     |            |   0%
# conda-verify-2.0.0   | 38 KB     | ########## | 100%
#
# glob2-0.6            | 17 KB     |            |   0%
# glob2-0.6            | 17 KB     | #########2 |  93%
# glob2-0.6            | 17 KB     | ########## | 100%
#
# hdf5-1.10.2          | 34.8 MB   |            |   0%
# hdf5-1.10.2          | 34.8 MB   |            |   0%
# hdf5-1.10.2          | 34.8 MB   | 1          |   2%
# hdf5-1.10.2          | 34.8 MB   | 6          |   6%
# hdf5-1.10.2          | 34.8 MB   | #4         |  14%
# hdf5-1.10.2          | 34.8 MB   | ##2        |  23%
# hdf5-1.10.2          | 34.8 MB   | ##9        |  30%
# hdf5-1.10.2          | 34.8 MB   | ###8       |  38%
# hdf5-1.10.2          | 34.8 MB   | ####6      |  47%
# hdf5-1.10.2          | 34.8 MB   | #####4     |  54%
# hdf5-1.10.2          | 34.8 MB   | ######2    |  63%
# hdf5-1.10.2          | 34.8 MB   | #######    |  70%
# hdf5-1.10.2          | 34.8 MB   | #######7   |  78%
# hdf5-1.10.2          | 34.8 MB   | ########9  |  90%
# hdf5-1.10.2          | 34.8 MB   | #########7 |  98%
# hdf5-1.10.2          | 34.8 MB   | ########## | 100%
#
# rope-0.10.7          | 279 KB    |            |   0%
# rope-0.10.7          | 279 KB    | ########## | 100%
#
# nltk-3.3.0           | 2.0 MB    |            |   0%
# nltk-3.3.0           | 2.0 MB    |            |   1%
# nltk-3.3.0           | 2.0 MB    | ######1    |  61%
# nltk-3.3.0           | 2.0 MB    | ########## | 100%
#
# fastcache-1.0.2      | 32 KB     |            |   0%
# fastcache-1.0.2      | 32 KB     | #####      |  50%
# fastcache-1.0.2      | 32 KB     | ########## | 100%
#
# lazy-object-proxy-1. | 31 KB     |            |   0%
# lazy-object-proxy-1. | 31 KB     | #####      |  51%
# lazy-object-proxy-1. | 31 KB     | ########## | 100%
#
# astroid-1.6.3        | 477 KB    |            |   0%
# astroid-1.6.3        | 477 KB    | 3          |   3%
# astroid-1.6.3        | 477 KB    | ########## | 100%
#
# _ipyw_jlab_nb_ext_co | 4 KB      |            |   0%
# _ipyw_jlab_nb_ext_co | 4 KB      | ########## | 100%
#
# bzip2-1.0.6          | 145 KB    |            |   0%
# bzip2-1.0.6          | 145 KB    | #1         |  11%
# bzip2-1.0.6          | 145 KB    | ########## | 100%
#
# msgpack-python-0.5.6 | 81 KB     |            |   0%
# msgpack-python-0.5.6 | 81 KB     | ########## | 100%
#
# cryptography-2.7     | 564 KB    |            |   0%
# cryptography-2.7     | 564 KB    | ########## | 100%
#
# terminado-0.8.1      | 21 KB     |            |   0%
# terminado-0.8.1      | 21 KB     | #######6   |  76%
# terminado-0.8.1      | 21 KB     | ########## | 100%
#
# urllib3-1.22         | 155 KB    |            |   0%
# urllib3-1.22         | 155 KB    | #          |  10%
# urllib3-1.22         | 155 KB    | ########## | 100%
#
# mpmath-1.0.0         | 904 KB    |            |   0%
# mpmath-1.0.0         | 904 KB    | 1          |   2%
# mpmath-1.0.0         | 904 KB    | ##6        |  27%
# mpmath-1.0.0         | 904 KB    | ########8  |  88%
# mpmath-1.0.0         | 904 KB    | ########## | 100%
#
# conda-4.7.11         | 3.0 MB    |            |   0%
# conda-4.7.11         | 3.0 MB    | ########## | 100%
#
# mkl_fft-1.0.1        | 113 KB    |            |   0%
# mkl_fft-1.0.1        | 113 KB    | #4         |  14%
# mkl_fft-1.0.1        | 113 KB    | ########## | 100%
#
# traitlets-4.3.2      | 131 KB    |            |   0%
# traitlets-4.3.2      | 131 KB    | ########## | 100%
#
# dask-0.17.5          | 4 KB      |            |   0%
# dask-0.17.5          | 4 KB      | ########## | 100%
#
# wcwidth-0.1.7        | 25 KB     |            |   0%
# wcwidth-0.1.7        | 25 KB     | ########## | 100%
#
# six-1.11.0           | 21 KB     |            |   0%
# six-1.11.0           | 21 KB     | #######5   |  75%
# six-1.11.0           | 21 KB     | ########## | 100%
#
# pycurl-7.43.0.3      | 67 KB     |            |   0%
# pycurl-7.43.0.3      | 67 KB     | ########## | 100%
#
# sphinxcontrib-1.0    | 3 KB      |            |   0%
# sphinxcontrib-1.0    | 3 KB      | ########## | 100%
#
# more-itertools-4.1.0 | 76 KB     |            |   0%
# more-itertools-4.1.0 | 76 KB     | ##1        |  21%
# more-itertools-4.1.0 | 76 KB     | ########## | 100%
#
# locket-0.2.0         | 8 KB      |            |   0%
# locket-0.2.0         | 8 KB      | ########## | 100%
#
# menuinst-1.4.14      | 92 KB     |            |   0%
# menuinst-1.4.14      | 92 KB     | #7         |  17%
# menuinst-1.4.14      | 92 KB     | ########## | 100%
#
# nose-1.3.7           | 241 KB    |            |   0%
# nose-1.3.7           | 241 KB    | ########## | 100%
#
# et_xmlfile-1.0.1     | 20 KB     |            |   0%
# et_xmlfile-1.0.1     | 20 KB     | ########## | 100%
#
# werkzeug-0.14.1      | 424 KB    |            |   0%
# werkzeug-0.14.1      | 424 KB    | 3          |   4%
# werkzeug-0.14.1      | 424 KB    | ########## | 100%
#
# olefile-0.45.1       | 47 KB     |            |   0%
# olefile-0.45.1       | 47 KB     | ###3       |  34%
# olefile-0.45.1       | 47 KB     | ########## | 100%
#
# pandoc-1.19.2.1      | 18.7 MB   |            |   0%
# pandoc-1.19.2.1      | 18.7 MB   |            |   0%
# pandoc-1.19.2.1      | 18.7 MB   | #          |  10%
# pandoc-1.19.2.1      | 18.7 MB   | ##2        |  22%
# pandoc-1.19.2.1      | 18.7 MB   | ####       |  40%
# pandoc-1.19.2.1      | 18.7 MB   | #####3     |  54%
# pandoc-1.19.2.1      | 18.7 MB   | ######8    |  68%
# pandoc-1.19.2.1      | 18.7 MB   | ########   |  81%
# pandoc-1.19.2.1      | 18.7 MB   | #########6 |  96%
# pandoc-1.19.2.1      | 18.7 MB   | ########## | 100%
#
# sphinxcontrib-websup | 36 KB     |            |   0%
# sphinxcontrib-websup | 36 KB     | ########## | 100%
#
# zlib-1.2.11          | 237 KB    |            |   0%
# zlib-1.2.11          | 237 KB    | ########## | 100%
#
# qtconsole-4.3.1      | 168 KB    |            |   0%
# qtconsole-4.3.1      | 168 KB    | 9          |  10%
# qtconsole-4.3.1      | 168 KB    | ########## | 100%
#
# xlsxwriter-1.0.4     | 207 KB    |            |   0%
# xlsxwriter-1.0.4     | 207 KB    | 7          |   8%
# xlsxwriter-1.0.4     | 207 KB    | ########## | 100%
#
# pytest-openfiles-0.3 | 9 KB      |            |   0%
# pytest-openfiles-0.3 | 9 KB      | ########## | 100%
#
# sqlite-3.28.0        | 945 KB    |            |   0%
# sqlite-3.28.0        | 945 KB    | ########## | 100%
#
# freetype-2.8         | 468 KB    |            |   0%
# freetype-2.8         | 468 KB    | 3          |   3%
# freetype-2.8         | 468 KB    | ####4      |  44%
# freetype-2.8         | 468 KB    | ########## | 100%
#
# flask-1.0.2          | 138 KB    |            |   0%
# flask-1.0.2          | 138 KB    | #1         |  12%
# flask-1.0.2          | 138 KB    | ########## | 100%
#
# jupyter-1.0.0        | 6 KB      |            |   0%
# jupyter-1.0.0        | 6 KB      | ########## | 100%
#
# datashape-0.5.4      | 99 KB     |            |   0%
# datashape-0.5.4      | 99 KB     | #6         |  16%
# datashape-0.5.4      | 99 KB     | ########## | 100%
#
# heapdict-1.0.0       | 8 KB      |            |   0%
# heapdict-1.0.0       | 8 KB      | ########## | 100%
#
# jupyterlab-0.32.1    | 10.1 MB   |            |   0%
# jupyterlab-0.32.1    | 10.1 MB   |            |   0%
# jupyterlab-0.32.1    | 10.1 MB   | #4         |  15%
# jupyterlab-0.32.1    | 10.1 MB   | ####       |  40%
# jupyterlab-0.32.1    | 10.1 MB   | ######9    |  70%
# jupyterlab-0.32.1    | 10.1 MB   | #########6 |  97%
# jupyterlab-0.32.1    | 10.1 MB   | ########## | 100%
#
# distributed-1.21.8   | 800 KB    |            |   0%
# distributed-1.21.8   | 800 KB    | 1          |   2%
# distributed-1.21.8   | 800 KB    | ########## | 100%
#
# pycosat-0.6.3        | 102 KB    |            |   0%
# pycosat-0.6.3        | 102 KB    | #5         |  16%
# pycosat-0.6.3        | 102 KB    | ########## | 100%
#
# jupyter_client-5.2.3 | 188 KB    |            |   0%
# jupyter_client-5.2.3 | 188 KB    | 8          |   9%
# jupyter_client-5.2.3 | 188 KB    | ########## | 100%
#
# mccabe-0.6.1         | 14 KB     |            |   0%
# mccabe-0.6.1         | 14 KB     | ########## | 100%
#
# numpy-base-1.14.3    | 3.8 MB    |            |   0%
# numpy-base-1.14.3    | 3.8 MB    |            |   0%
# numpy-base-1.14.3    | 3.8 MB    | #######5   |  75%
# numpy-base-1.14.3    | 3.8 MB    | ########## | 100%
#
# sortedcollections-0. | 15 KB     |            |   0%
# sortedcollections-0. | 15 KB     | ########## | 100%
#
# libtiff-4.0.9        | 831 KB    |            |   0%
# libtiff-4.0.9        | 831 KB    | ########## | 100%
#
# chardet-3.0.4        | 209 KB    |            |   0%
# chardet-3.0.4        | 209 KB    | ########## | 100%
#
# path.py-11.0.1       | 54 KB     |            |   0%
# path.py-11.0.1       | 54 KB     | ##9        |  30%
# path.py-11.0.1       | 54 KB     | ########## | 100%
#
# libcurl-7.64.1       | 283 KB    |            |   0%
# libcurl-7.64.1       | 283 KB    | 5          |   6%
# libcurl-7.64.1       | 283 KB    | ########## | 100%
#
# greenlet-0.4.13      | 20 KB     |            |   0%
# greenlet-0.4.13      | 20 KB     | #######8   |  78%
# greenlet-0.4.13      | 20 KB     | ########## | 100%
#
# pandas-0.23.0        | 10.4 MB   |            |   0%
# pandas-0.23.0        | 10.4 MB   |            |   0%
# pandas-0.23.0        | 10.4 MB   | ##7        |  28%
# pandas-0.23.0        | 10.4 MB   | #####8     |  59%
# pandas-0.23.0        | 10.4 MB   | ########2  |  83%
# pandas-0.23.0        | 10.4 MB   | ########## | 100%
#
# pluggy-0.6.0         | 23 KB     |            |   0%
# pluggy-0.6.0         | 23 KB     | #######    |  71%
# pluggy-0.6.0         | 23 KB     | ########## | 100%
#
# pycrypto-2.6.1       | 477 KB    |            |   0%
# pycrypto-2.6.1       | 477 KB    | ########## | 100%
#
# partd-0.3.8          | 31 KB     |            |   0%
# partd-0.3.8          | 31 KB     | ########## | 100%
#
# isort-4.3.4          | 76 KB     |            |   0%
# isort-4.3.4          | 76 KB     | ##         |  21%
# isort-4.3.4          | 76 KB     | ########## | 100%
#
# zict-0.1.3           | 18 KB     |            |   0%
# zict-0.1.3           | 18 KB     | ########7  |  88%
# zict-0.1.3           | 18 KB     | ########## | 100%
#
# conda-build-3.10.5   | 453 KB    |            |   0%
# conda-build-3.10.5   | 453 KB    | 3          |   4%
# conda-build-3.10.5   | 453 KB    | ########## | 100%
#
# icc_rt-2017.0.4      | 8.0 MB    |            |   0%
# icc_rt-2017.0.4      | 8.0 MB    | ######7    |  68%
# icc_rt-2017.0.4      | 8.0 MB    | ########## | 100%
#
# psutil-5.4.5         | 322 KB    |            |   0%
# psutil-5.4.5         | 322 KB    | 4          |   5%
# psutil-5.4.5         | 322 KB    | ########## | 100%
#
# pytest-astropy-0.3.0 | 6 KB      |            |   0%
# pytest-astropy-0.3.0 | 6 KB      | ########## | 100%
#
# ipython-6.4.0        | 1.1 MB    |            |   0%
# ipython-6.4.0        | 1.1 MB    | 1          |   1%
# ipython-6.4.0        | 1.1 MB    | ###9       |  39%
# ipython-6.4.0        | 1.1 MB    | ########## | 100%
#
# libarchive-3.3.3     | 1.4 MB    |            |   0%
# libarchive-3.3.3     | 1.4 MB    | ########## | 100%
#
# contextlib2-0.5.5    | 15 KB     |            |   0%
# contextlib2-0.5.5    | 15 KB     | ########## | 100%
#
# alabaster-0.7.10     | 15 KB     |            |   0%
# alabaster-0.7.10     | 15 KB     | ########## | 100%
#
# toolz-0.9.0          | 92 KB     |            |   0%
# toolz-0.9.0          | 92 KB     | #7         |  17%
# toolz-0.9.0          | 92 KB     | ########## | 100%
#
# jsonschema-2.6.0     | 104 KB    |            |   0%
# jsonschema-2.6.0     | 104 KB    | #5         |  15%
# jsonschema-2.6.0     | 104 KB    | ########## | 100%
#
# jedi-0.12.0          | 224 KB    |            |   0%
# jedi-0.12.0          | 224 KB    | 7          |   7%
# jedi-0.12.0          | 224 KB    | ########## | 100%
#
# bottleneck-1.2.1     | 113 KB    |            |   0%
# bottleneck-1.2.1     | 113 KB    | ########## | 100%
#
# networkx-2.1         | 1.8 MB    |            |   0%
# networkx-2.1         | 1.8 MB    |            |   1%
# networkx-2.1         | 1.8 MB    | ##1        |  21%
# networkx-2.1         | 1.8 MB    | ######2    |  62%
# networkx-2.1         | 1.8 MB    | ########## | 100%
#
# qtpy-1.4.1           | 44 KB     |            |   0%
# qtpy-1.4.1           | 44 KB     | ###6       |  36%
# qtpy-1.4.1           | 44 KB     | ########## | 100%
#
# cytoolz-0.9.0.1      | 326 KB    |            |   0%
# cytoolz-0.9.0.1      | 326 KB    | 4          |   5%
# cytoolz-0.9.0.1      | 326 KB    | ####4      |  44%
# cytoolz-0.9.0.1      | 326 KB    | #######3   |  74%
# cytoolz-0.9.0.1      | 326 KB    | ########## | 100%
#
# docutils-0.14        | 695 KB    |            |   0%
# docutils-0.14        | 695 KB    | 2          |   2%
# docutils-0.14        | 695 KB    | ########## | 100%
#
# dask-core-0.17.5     | 1.0 MB    |            |   0%
# dask-core-0.17.5     | 1.0 MB    | 1          |   2%
# dask-core-0.17.5     | 1.0 MB    | ########7  |  88%
# dask-core-0.17.5     | 1.0 MB    | ########## | 100%
#
# lz4-c-1.8.1.2        | 217 KB    |            |   0%
# lz4-c-1.8.1.2        | 217 KB    | ########## | 100%
#
# mkl_random-1.0.1     | 267 KB    |            |   0%
# mkl_random-1.0.1     | 267 KB    | 5          |   6%
# mkl_random-1.0.1     | 267 KB    | ########## | 100%
#
# filelock-3.0.4       | 12 KB     |            |   0%
# filelock-3.0.4       | 12 KB     | ########## | 100%
#
# cython-0.28.2        | 2.7 MB    |            |   0%
# cython-0.28.2        | 2.7 MB    | ########## | 100%
#
# pickleshare-0.7.4    | 12 KB     |            |   0%
# pickleshare-0.7.4    | 12 KB     | ########## | 100%
#
# simplegeneric-0.8.1  | 10 KB     |            |   0%
# simplegeneric-0.8.1  | 10 KB     | ########## | 100%
#
# idna-2.6             | 123 KB    |            |   0%
# idna-2.6             | 123 KB    | #3         |  13%
# idna-2.6             | 123 KB    | ########## | 100%
#
# pyflakes-1.6.0       | 127 KB    |            |   0%
# pyflakes-1.6.0       | 127 KB    | #2         |  13%
# pyflakes-1.6.0       | 127 KB    | ########## | 100%
#
# widgetsnbextension-3 | 1.7 MB    |            |   0%
# widgetsnbextension-3 | 1.7 MB    |            |   1%
# widgetsnbextension-3 | 1.7 MB    | ##2        |  23%
# widgetsnbextension-3 | 1.7 MB    | ########## | 100%
#
# xz-5.2.4             | 812 KB    |            |   0%
# xz-5.2.4             | 812 KB    | ########## | 100%
#
# ruamel_yaml-0.15.35  | 260 KB    |            |   0%
# ruamel_yaml-0.15.35  | 260 KB    | ########## | 100%
#
# pathlib2-2.3.2       | 33 KB     |            |   0%
# pathlib2-2.3.2       | 33 KB     | ####8      |  49%
# pathlib2-2.3.2       | 33 KB     | ########## | 100%
#
# unicodecsv-0.14.1    | 26 KB     |            |   0%
# unicodecsv-0.14.1    | 26 KB     | ########## | 100%
#
# win_inet_pton-1.0.1  | 5 KB      |            |   0%
# win_inet_pton-1.0.1  | 5 KB      | ########## | 100%
#
# pytest-remotedata-0. | 12 KB     |            |   0%
# pytest-remotedata-0. | 12 KB     | ########## | 100%
#
# tblib-1.3.2          | 16 KB     |            |   0%
# tblib-1.3.2          | 16 KB     | ########## | 100%
#
# get_terminal_size-1. | 3 KB      |            |   0%
# get_terminal_size-1. | 3 KB      | ########## | 100%
#
# boto-2.48.0          | 1.6 MB    |            |   0%
# boto-2.48.0          | 1.6 MB    |            |   1%
# boto-2.48.0          | 1.6 MB    | ########3  |  84%
# boto-2.48.0          | 1.6 MB    | ########## | 100%
#
# pandocfilters-1.4.2  | 13 KB     |            |   0%
# pandocfilters-1.4.2  | 13 KB     | ########## | 100%
#
# notebook-5.5.0       | 7.0 MB    |            |   0%
# notebook-5.5.0       | 7.0 MB    |            |   0%
# notebook-5.5.0       | 7.0 MB    | #3         |  13%
# notebook-5.5.0       | 7.0 MB    | ####       |  40%
# notebook-5.5.0       | 7.0 MB    | ########   |  81%
# notebook-5.5.0       | 7.0 MB    | ########## | 100%
#
# send2trash-1.5.0     | 16 KB     |            |   0%
# send2trash-1.5.0     | 16 KB     | ########## | 100%
#
# cffi-1.11.5          | 213 KB    |            |   0%
# cffi-1.11.5          | 213 KB    | 7          |   7%
# cffi-1.11.5          | 213 KB    | ########## | 100%
#
# blosc-1.14.3         | 652 KB    |            |   0%
# blosc-1.14.3         | 652 KB    | 2          |   2%
# blosc-1.14.3         | 652 KB    | #####8     |  59%
# blosc-1.14.3         | 652 KB    | ########## | 100%
#
# sphinx-1.7.4         | 1.6 MB    |            |   0%
# sphinx-1.7.4         | 1.6 MB    |            |   1%
# sphinx-1.7.4         | 1.6 MB    | ########## | 100%
#
# numba-0.38.0         | 2.4 MB    |            |   0%
# numba-0.38.0         | 2.4 MB    |            |   1%
# numba-0.38.0         | 2.4 MB    | 3          |   3%
# numba-0.38.0         | 2.4 MB    | #1         |  12%
# numba-0.38.0         | 2.4 MB    | #9         |  20%
# numba-0.38.0         | 2.4 MB    | ##6        |  26%
# numba-0.38.0         | 2.4 MB    | ###2       |  33%
# numba-0.38.0         | 2.4 MB    | ####3      |  44%
# numba-0.38.0         | 2.4 MB    | #####3     |  53%
# numba-0.38.0         | 2.4 MB    | ######5    |  65%
# numba-0.38.0         | 2.4 MB    | #######4   |  74%
# numba-0.38.0         | 2.4 MB    | #########2 |  92%
# numba-0.38.0         | 2.4 MB    | ########## | 100%
#
# wincertstore-0.2     | 13 KB     |            |   0%
# wincertstore-0.2     | 13 KB     | ########## | 100%
#
# pep8-1.7.1           | 70 KB     |            |   0%
# pep8-1.7.1           | 70 KB     | ########## | 100%
#
# requests-2.18.4      | 92 KB     |            |   0%
# requests-2.18.4      | 92 KB     | ########## | 100%
#
# tqdm-4.32.1          | 48 KB     |            |   0%
# tqdm-4.32.1          | 48 KB     | ########## | 100%
#
# yaml-0.1.7           | 103 KB    |            |   0%
# yaml-0.1.7           | 103 KB    | ########## | 100%
#
# typing-3.6.4         | 45 KB     |            |   0%
# typing-3.6.4         | 45 KB     | ###5       |  36%
# typing-3.6.4         | 45 KB     | ########## | 100%
#
# singledispatch-3.4.0 | 15 KB     |            |   0%
# singledispatch-3.4.0 | 15 KB     | ########## | 100%
#
# certifi-2019.6.16    | 156 KB    |            |   0%
# certifi-2019.6.16    | 156 KB    | #          |  10%
# certifi-2019.6.16    | 156 KB    | ########## | 100%
#
# ipywidgets-7.2.1     | 145 KB    |            |   0%
# ipywidgets-7.2.1     | 145 KB    | #1         |  11%
# ipywidgets-7.2.1     | 145 KB    | ########## | 100%
#
# vs2015_runtime-14.15 | 2.4 MB    |            |   0%
# vs2015_runtime-14.15 | 2.4 MB    | ########## | 100%
#
# pyopenssl-18.0.0     | 83 KB     |            |   0%
# pyopenssl-18.0.0     | 83 KB     | #9         |  19%
# pyopenssl-18.0.0     | 83 KB     | ########## | 100%
#
# bitarray-0.8.1       | 63 KB     |            |   0%
# bitarray-0.8.1       | 63 KB     | ##5        |  26%
# bitarray-0.8.1       | 63 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# pillow-5.1.0         | 648 KB    |            |   0%
# pillow-5.1.0         | 648 KB    | 2          |   2%
# pillow-5.1.0         | 648 KB    | ########## | 100%
#
# anaconda-client-1.6. | 159 KB    |            |   0%
# anaconda-client-1.6. | 159 KB    | ########## | 100%
#
# libsodium-1.0.16     | 585 KB    |            |   0%
# libsodium-1.0.16     | 585 KB    | 2          |   3%
# libsodium-1.0.16     | 585 KB    | ########## | 100%
#
# webencodings-0.5.1   | 19 KB     |            |   0%
# webencodings-0.5.1   | 19 KB     | ########3  |  84%
# webencodings-0.5.1   | 19 KB     | ########## | 100%
#
# py-1.5.3             | 136 KB    |            |   0%
# py-1.5.3             | 136 KB    | #1         |  12%
# py-1.5.3             | 136 KB    | #####8     |  59%
# py-1.5.3             | 136 KB    | ########## | 100%
#
# zeromq-4.2.5         | 9.5 MB    |            |   0%
# zeromq-4.2.5         | 9.5 MB    |            |   0%
# zeromq-4.2.5         | 9.5 MB    | 4          |   5%
# zeromq-4.2.5         | 9.5 MB    | ####4      |  44%
# zeromq-4.2.5         | 9.5 MB    | #######5   |  75%
# zeromq-4.2.5         | 9.5 MB    | ########## | 100%
#
# python-libarchive-c- | 20 KB     |            |   0%
# python-libarchive-c- | 20 KB     | #######8   |  79%
# python-libarchive-c- | 20 KB     | ########## | 100%
#
# bokeh-0.12.16        | 4.2 MB    |            |   0%
# bokeh-0.12.16        | 4.2 MB    |            |   0%
# bokeh-0.12.16        | 4.2 MB    | 9          |   9%
# bokeh-0.12.16        | 4.2 MB    | ##3        |  23%
# bokeh-0.12.16        | 4.2 MB    | ###3       |  33%
# bokeh-0.12.16        | 4.2 MB    | #########6 |  97%
# bokeh-0.12.16        | 4.2 MB    | ########## | 100%
#
# scikit-image-0.13.1  | 22.5 MB   |            |   0%
# scikit-image-0.13.1  | 22.5 MB   |            |   0%
# scikit-image-0.13.1  | 22.5 MB   | #          |  11%
# scikit-image-0.13.1  | 22.5 MB   | ##1        |  22%
# scikit-image-0.13.1  | 22.5 MB   | ###3       |  34%
# scikit-image-0.13.1  | 22.5 MB   | ####3      |  44%
# scikit-image-0.13.1  | 22.5 MB   | #####5     |  55%
# scikit-image-0.13.1  | 22.5 MB   | ######7    |  68%
# scikit-image-0.13.1  | 22.5 MB   | #######9   |  79%
# scikit-image-0.13.1  | 22.5 MB   | #########1 |  91%
# scikit-image-0.13.1  | 22.5 MB   | ########## | 100%
#
# sympy-1.1.1          | 7.0 MB    |            |   0%
# sympy-1.1.1          | 7.0 MB    |            |   0%
# sympy-1.1.1          | 7.0 MB    | ####2      |  43%
# sympy-1.1.1          | 7.0 MB    | #######9   |  80%
# sympy-1.1.1          | 7.0 MB    | ########## | 100%
#
# tk-8.6.8             | 3.8 MB    |            |   0%
# tk-8.6.8             | 3.8 MB    | ########## | 100%
#
# nbformat-4.4.0       | 157 KB    |            |   0%
# nbformat-4.4.0       | 157 KB    | ########## | 100%
#
# curl-7.64.1          | 120 KB    |            |   0%
# curl-7.64.1          | 120 KB    | #3         |  13%
# curl-7.64.1          | 120 KB    | ########## | 100%
#
# multipledispatch-0.5 | 18 KB     |            |   0%
# multipledispatch-0.5 | 18 KB     | ########6  |  87%
# multipledispatch-0.5 | 18 KB     | ########## | 100%
#
# openpyxl-2.5.3       | 323 KB    |            |   0%
# openpyxl-2.5.3       | 323 KB    | 4          |   5%
# openpyxl-2.5.3       | 323 KB    | ########## | 100%
#
# bleach-2.1.3         | 33 KB     |            |   0%
# bleach-2.1.3         | 33 KB     | ####8      |  48%
# bleach-2.1.3         | 33 KB     | ########## | 100%
#
# mistune-0.8.3        | 198 KB    |            |   0%
# mistune-0.8.3        | 198 KB    | 8          |   8%
# mistune-0.8.3        | 198 KB    | ########## | 100%
#
# matplotlib-2.2.2     | 6.5 MB    |            |   0%
# matplotlib-2.2.2     | 6.5 MB    | ####7      |  47%
# matplotlib-2.2.2     | 6.5 MB    | ########## | 100%
#
# conda-env-2.6.0      | 3 KB      |            |   0%
# conda-env-2.6.0      | 3 KB      | ########## | 100%
#
# libpng-1.6.37        | 598 KB    |            |   0%
# libpng-1.6.37        | 598 KB    | ########## | 100%
#
# anaconda-project-0.8 | 495 KB    |            |   0%
# anaconda-project-0.8 | 495 KB    | 3          |   3%
# anaconda-project-0.8 | 495 KB    | ########   |  81%
# anaconda-project-0.8 | 495 KB    | ########## | 100%
#
# pycodestyle-2.4.0    | 77 KB     |            |   0%
# pycodestyle-2.4.0    | 77 KB     | ##         |  21%
# pycodestyle-2.4.0    | 77 KB     | ########## | 100%
#
# sortedcontainers-1.5 | 47 KB     |            |   0%
# sortedcontainers-1.5 | 47 KB     | ###4       |  34%
# sortedcontainers-1.5 | 47 KB     | ########## | 100%
#
# snowballstemmer-1.2. | 85 KB     |            |   0%
# snowballstemmer-1.2. | 85 KB     | ########## | 100%
#
# python-3.6.5         | 21.6 MB   |            |   0%
# python-3.6.5         | 21.6 MB   |            |   0%
# python-3.6.5         | 21.6 MB   | 2          |   2%
# python-3.6.5         | 21.6 MB   | 4          |   5%
# python-3.6.5         | 21.6 MB   | 8          |   8%
# python-3.6.5         | 21.6 MB   | #2         |  12%
# python-3.6.5         | 21.6 MB   | #5         |  16%
# python-3.6.5         | 21.6 MB   | ##2        |  23%
# python-3.6.5         | 21.6 MB   | ##9        |  30%
# python-3.6.5         | 21.6 MB   | ###7       |  38%
# python-3.6.5         | 21.6 MB   | ####8      |  49%
# python-3.6.5         | 21.6 MB   | #####8     |  59%
# python-3.6.5         | 21.6 MB   | ######8    |  69%
# python-3.6.5         | 21.6 MB   | #######8   |  79%
# python-3.6.5         | 21.6 MB   | ########9  |  89%
# python-3.6.5         | 21.6 MB   | ########## | 100%
#
# libssh2-1.8.2        | 186 KB    |            |   0%
# libssh2-1.8.2        | 186 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# ply-3.11             | 80 KB     |            |   0%
# ply-3.11             | 80 KB     | ########## | 100%
#
# gevent-1.3.0         | 1.6 MB    |            |   0%
# gevent-1.3.0         | 1.6 MB    |            |   1%
# gevent-1.3.0         | 1.6 MB    | #4         |  15%
# gevent-1.3.0         | 1.6 MB    | #####      |  51%
# gevent-1.3.0         | 1.6 MB    | ########## | 100%
#
# sip-4.19.8           | 282 KB    |            |   0%
# sip-4.19.8           | 282 KB    | ########## | 100%
#
# clyent-1.2.2         | 19 KB     |            |   0%
# clyent-1.2.2         | 19 KB     | ########6  |  86%
# clyent-1.2.2         | 19 KB     | ########## | 100%
#
# h5py-2.7.1           | 801 KB    |            |   0%
# h5py-2.7.1           | 801 KB    | 1          |   2%
# h5py-2.7.1           | 801 KB    | ######9    |  70%
# h5py-2.7.1           | 801 KB    | ########## | 100%
#
# pytest-arraydiff-0.2 | 14 KB     |            |   0%
# pytest-arraydiff-0.2 | 14 KB     | ########## | 100%
#
# intel-openmp-2018.0. | 1.4 MB    |            |   0%
# intel-openmp-2018.0. | 1.4 MB    | 1          |   1%
# intel-openmp-2018.0. | 1.4 MB    | ######3    |  63%
# intel-openmp-2018.0. | 1.4 MB    | ########## | 100%
#
# pygments-2.2.0       | 1.4 MB    |            |   0%
# pygments-2.2.0       | 1.4 MB    | 1          |   1%
# pygments-2.2.0       | 1.4 MB    | ##1        |  22%
# pygments-2.2.0       | 1.4 MB    | ######6    |  67%
# pygments-2.2.0       | 1.4 MB    | ########## | 100%
#
# pysocks-1.6.8        | 23 KB     |            |   0%
# pysocks-1.6.8        | 23 KB     | ########## | 100%
#
# python-dateutil-2.7. | 261 KB    |            |   0%
# python-dateutil-2.7. | 261 KB    | 6          |   6%
# python-dateutil-2.7. | 261 KB    | ########## | 100%
#
# zstd-1.3.7           | 536 KB    |            |   0%
# zstd-1.3.7           | 536 KB    | ########## | 100%
#
# sqlalchemy-1.2.7     | 1.6 MB    |            |   0%
# sqlalchemy-1.2.7     | 1.6 MB    |            |   1%
# sqlalchemy-1.2.7     | 1.6 MB    | ##         |  21%
# sqlalchemy-1.2.7     | 1.6 MB    | ########1  |  82%
# sqlalchemy-1.2.7     | 1.6 MB    | ########## | 100%
#
# setuptools-39.1.0    | 570 KB    |            |   0%
# setuptools-39.1.0    | 570 KB    | 2          |   3%
# setuptools-39.1.0    | 570 KB    | ########## | 100%
#
# qtawesome-0.4.4      | 159 KB    |            |   0%
# qtawesome-0.4.4      | 159 KB    | #          |  10%
# qtawesome-0.4.4      | 159 KB    | ########## | 100%
#
# jupyter_console-5.2. | 52 KB     |            |   0%
# jupyter_console-5.2. | 52 KB     | ###        |  31%
# jupyter_console-5.2. | 52 KB     | ########## | 100%
#
# snappy-1.1.7         | 82 KB     |            |   0%
# snappy-1.1.7         | 82 KB     | ########## | 100%
#
# xlwings-0.11.8       | 782 KB    |            |   0%
# xlwings-0.11.8       | 782 KB    | 2          |   2%
# xlwings-0.11.8       | 782 KB    | #####7     |  57%
# xlwings-0.11.8       | 782 KB    | ########## | 100%
#
# nbconvert-5.3.1      | 419 KB    |            |   0%
# nbconvert-5.3.1      | 419 KB    | 3          |   4%
# nbconvert-5.3.1      | 419 KB    | ########## | 100%
#
# scipy-1.1.0          | 13.5 MB   |            |   0%
# scipy-1.1.0          | 13.5 MB   | ####5      |  46%
# scipy-1.1.0          | 13.5 MB   | ########## | 100%
#
# statsmodels-0.9.0    | 8.3 MB    |            |   0%
# statsmodels-0.9.0    | 8.3 MB    |            |   0%
# statsmodels-0.9.0    | 8.3 MB    | 1          |   2%
# statsmodels-0.9.0    | 8.3 MB    | 3          |   3%
# statsmodels-0.9.0    | 8.3 MB    | 4          |   5%
# statsmodels-0.9.0    | 8.3 MB    | 6          |   7%
# statsmodels-0.9.0    | 8.3 MB    | 9          |  10%
# statsmodels-0.9.0    | 8.3 MB    | #1         |  12%
# statsmodels-0.9.0    | 8.3 MB    | #4         |  14%
# statsmodels-0.9.0    | 8.3 MB    | #6         |  16%
# statsmodels-0.9.0    | 8.3 MB    | #9         |  19%
# statsmodels-0.9.0    | 8.3 MB    | ##2        |  23%
# statsmodels-0.9.0    | 8.3 MB    | ##6        |  27%
# statsmodels-0.9.0    | 8.3 MB    | ###1       |  31%
# statsmodels-0.9.0    | 8.3 MB    | ###8       |  38%
# statsmodels-0.9.0    | 8.3 MB    | ####5      |  45%
# statsmodels-0.9.0    | 8.3 MB    | #####2     |  53%
# statsmodels-0.9.0    | 8.3 MB    | ######     |  60%
# statsmodels-0.9.0    | 8.3 MB    | ######6    |  66%
# statsmodels-0.9.0    | 8.3 MB    | #######4   |  74%
# statsmodels-0.9.0    | 8.3 MB    | ########2  |  83%
# statsmodels-0.9.0    | 8.3 MB    | #########1 |  91%
# statsmodels-0.9.0    | 8.3 MB    | ########## | 100%
#
# jupyterlab_launcher- | 25 KB     |            |   0%
# jupyterlab_launcher- | 25 KB     | ######4    |  65%
# jupyterlab_launcher- | 25 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# pycparser-2.18       | 169 KB    |            |   0%
# pycparser-2.18       | 169 KB    | 9          |   9%
# pycparser-2.18       | 169 KB    | ########## | 100%
#
# spyder-3.2.8         | 2.7 MB    |            |   0%
# spyder-3.2.8         | 2.7 MB    |            |   1%
# spyder-3.2.8         | 2.7 MB    | ####6      |  47%
# spyder-3.2.8         | 2.7 MB    | ########## | 100%
#
# ipykernel-4.8.2      | 146 KB    |            |   0%
# ipykernel-4.8.2      | 146 KB    | #          |  11%
# ipykernel-4.8.2      | 146 KB    | ########## | 100%
#
# jinja2-2.10          | 184 KB    |            |   0%
# jinja2-2.10          | 184 KB    | 8          |   9%
# jinja2-2.10          | 184 KB    | ########## | 100%
#
# kiwisolver-1.0.1     | 61 KB     |            |   0%
# kiwisolver-1.0.1     | 61 KB     | ##6        |  26%
# kiwisolver-1.0.1     | 61 KB     | ########## | 100%
#
# navigator-updater-0. | 1.3 MB    |            |   0%
# navigator-updater-0. | 1.3 MB    | ########## | 100%
#
# parso-0.2.0          | 117 KB    |            |   0%
# parso-0.2.0          | 117 KB    | #3         |  14%
# parso-0.2.0          | 117 KB    | ########## | 100%
#
# attrs-18.1.0         | 44 KB     |            |   0%
# attrs-18.1.0         | 44 KB     | ###6       |  36%
# attrs-18.1.0         | 44 KB     | ########## | 100%
#
# qt-5.9.7             | 92.3 MB   |            |   0%
# qt-5.9.7             | 92.3 MB   | 4          |   5%
# qt-5.9.7             | 92.3 MB   | #1         |  12%
# qt-5.9.7             | 92.3 MB   | ##2        |  23%
# qt-5.9.7             | 92.3 MB   | ##9        |  29%
# qt-5.9.7             | 92.3 MB   | ####       |  40%
# qt-5.9.7             | 92.3 MB   | ####8      |  48%
# qt-5.9.7             | 92.3 MB   | #####8     |  58%
# qt-5.9.7             | 92.3 MB   | #######    |  70%
# qt-5.9.7             | 92.3 MB   | ########2  |  83%
# qt-5.9.7             | 92.3 MB   | #########3 |  94%
# qt-5.9.7             | 92.3 MB   | ########## | 100%
#
# testpath-0.3.1       | 89 KB     |            |   0%
# testpath-0.3.1       | 89 KB     | #7         |  18%
# testpath-0.3.1       | 89 KB     | ########## | 100%
#
# win_unicode_console- | 31 KB     |            |   0%
# win_unicode_console- | 31 KB     | ########## | 100%
#
# pywinpty-0.5.1       | 44 KB     |            |   0%
# pywinpty-0.5.1       | 44 KB     | ###6       |  36%
# pywinpty-0.5.1       | 44 KB     | ########## | 100%
#
# pywavelets-0.5.2     | 4.0 MB    |            |   0%
# pywavelets-0.5.2     | 4.0 MB    | ########7  |  88%
# pywavelets-0.5.2     | 4.0 MB    | ########## | 100%
#
# bkcharts-0.2         | 128 KB    |            |   0%
# bkcharts-0.2         | 128 KB    | #2         |  13%
# bkcharts-0.2         | 128 KB    | ########## | 100%
#
# pytest-doctestplus-0 | 20 KB     |            |   0%
# pytest-doctestplus-0 | 20 KB     | ########   |  81%
# pytest-doctestplus-0 | 20 KB     | ########## | 100%
#
# lxml-4.2.1           | 1.1 MB    |            |   0%
# lxml-4.2.1           | 1.1 MB    | 1          |   1%
# lxml-4.2.1           | 1.1 MB    | ########## | 100%
#
# astropy-3.0.2        | 6.7 MB    |            |   0%
# astropy-3.0.2        | 6.7 MB    |            |   0%
# astropy-3.0.2        | 6.7 MB    | ###5       |  36%
# astropy-3.0.2        | 6.7 MB    | #######3   |  73%
# astropy-3.0.2        | 6.7 MB    | ########## | 100%
#
# asn1crypto-0.24.0    | 155 KB    |            |   0%
# asn1crypto-0.24.0    | 155 KB    | ########## | 100%
#
# imagesize-1.0.0      | 8 KB      |            |   0%
# imagesize-1.0.0      | 8 KB      | ########## | 100%
#
# pyzmq-17.0.0         | 399 KB    |            |   0%
# pyzmq-17.0.0         | 399 KB    | 4          |   4%
# pyzmq-17.0.0         | 399 KB    | ########## | 100%
#
# click-6.7            | 105 KB    |            |   0%
# click-6.7            | 105 KB    | #5         |  15%
# click-6.7            | 105 KB    | ########## | 100%
#
# jupyter_core-4.4.0   | 84 KB     |            |   0%
# jupyter_core-4.4.0   | 84 KB     | #9         |  19%
# jupyter_core-4.4.0   | 84 KB     | ###8       |  38%
# jupyter_core-4.4.0   | 84 KB     | ########## | 100%
#
# babel-2.5.3          | 4.7 MB    |            |   0%
# babel-2.5.3          | 4.7 MB    |            |   0%
# babel-2.5.3          | 4.7 MB    | 1          |   1%
# babel-2.5.3          | 4.7 MB    | 3          |   3%
# babel-2.5.3          | 4.7 MB    | 5          |   6%
# babel-2.5.3          | 4.7 MB    | 8          |   8%
# babel-2.5.3          | 4.7 MB    | #2         |  12%
# babel-2.5.3          | 4.7 MB    | #6         |  16%
# babel-2.5.3          | 4.7 MB    | ##         |  20%
# babel-2.5.3          | 4.7 MB    | ##3        |  24%
# babel-2.5.3          | 4.7 MB    | ##7        |  28%
# babel-2.5.3          | 4.7 MB    | ###1       |  32%
# babel-2.5.3          | 4.7 MB    | ###6       |  36%
# babel-2.5.3          | 4.7 MB    | ####1      |  42%
# babel-2.5.3          | 4.7 MB    | ####8      |  48%
# babel-2.5.3          | 4.7 MB    | #####7     |  57%
# babel-2.5.3          | 4.7 MB    | ######7    |  67%
# babel-2.5.3          | 4.7 MB    | ########   |  80%
# babel-2.5.3          | 4.7 MB    | #########1 |  91%
# babel-2.5.3          | 4.7 MB    | ########## | 100%
#
# pyodbc-4.0.23        | 62 KB     |            |   0%
# pyodbc-4.0.23        | 62 KB     | ##5        |  26%
# pyodbc-4.0.23        | 62 KB     | ########## | 100%
#
# libxslt-1.1.32       | 458 KB    |            |   0%
# libxslt-1.1.32       | 458 KB    | 3          |   3%
# libxslt-1.1.32       | 458 KB    | ########## | 100%
#
# numpy-1.14.3         | 41 KB     |            |   0%
# numpy-1.14.3         | 41 KB     | ###9       |  39%
# numpy-1.14.3         | 41 KB     | ########## | 100%
#
# pytest-3.5.1         | 314 KB    |            |   0%
# pytest-3.5.1         | 314 KB    | 5          |   5%
# pytest-3.5.1         | 314 KB    | ########## | 100%
#
# tornado-5.0.2        | 652 KB    |            |   0%
# tornado-5.0.2        | 652 KB    | 2          |   2%
# tornado-5.0.2        | 652 KB    | #####1     |  52%
# tornado-5.0.2        | 652 KB    | ########## | 100%
#
# decorator-4.3.0      | 16 KB     |            |   0%
# decorator-4.3.0      | 16 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... b''
# b''
# b'Enabling: jupyter_nbextensions_configurator\n- Writing config: C:\\Users\\ap18525\\.conda\\envs\\environment\\etc\\jupyter\n    - Validating...\n      jupyter_nbextensions_configurator 0.4.1 ok\nEnabling notebook nbextension nbextensions_configurator/config_menu/main...\nEnabling tree nbextension nbextensions_configurator/tree_tab/main...\n'
# ...
#
# Requirement already satisfied, skipping upgrade: pytz in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from matplotlib->hydrostats==0.78->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 3)) (2018.4)
#
# Requirement already satisfied, skipping upgrade: six>=1.10 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from matplotlib->hydrostats==0.78->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 3)) (1.11.0)
#
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from matplotlib->hydrostats==0.78->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 3)) (1.0.1)
#
# Requirement already satisfied, skipping upgrade: llvmlite>=0.23.0dev0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from numba->hydrostats==0.78->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 3)) (0.23.1)
#
# Requirement already satisfied, skipping upgrade: notebook in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (5.5.0)
#
# Requirement already satisfied, skipping upgrade: qtconsole in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (4.3.1)
#
# Requirement already satisfied, skipping upgrade: jupyter-console in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (5.2.0)
#
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (5.3.1)
#
# Requirement already satisfied, skipping upgrade: ipykernel in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (4.8.2)
#
# Requirement already satisfied, skipping upgrade: ipywidgets in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (7.2.1)
#
# Requirement already satisfied, skipping upgrade: ipython_genutils in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from traitlets>=4.2.2->traittypes==0.2.1->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 8)) (0.2.0)
#
# Requirement already satisfied, skipping upgrade: decorator in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from traitlets>=4.2.2->traittypes==0.2.1->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 8)) (4.3.0)
#
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->hydrostats==0.78->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 3)) (39.1.0)
#
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (17.0.0)
#
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (2.10)
#
# Requirement already satisfied, skipping upgrade: tornado>=4 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (5.0.2)
#
# Requirement already satisfied, skipping upgrade: nbformat in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (4.4.0)
#
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.4.0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (4.4.0)
#
# Requirement already satisfied, skipping upgrade: jupyter-client>=5.2.0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (5.2.3)
#
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (1.5.0)
#
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.8.1)
#
# Requirement already satisfied, skipping upgrade: ipython in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (6.4.0)
#
# Requirement already satisfied, skipping upgrade: prompt_toolkit<2.0.0,>=1.0.0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (1.0.15)
#
# Requirement already satisfied, skipping upgrade: pygments in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (2.2.0)
#
# Requirement already satisfied, skipping upgrade: mistune>=0.7.4 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.8.3)
#
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.2.3)
#
# Requirement already satisfied, skipping upgrade: bleach in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (2.1.3)
#
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (1.4.2)
#
# Requirement already satisfied, skipping upgrade: testpath in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.3.1)
#
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.2.0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipywidgets->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (3.2.1)
#
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jinja2->notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (1.0)
#
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from nbformat->notebook->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (2.6.0)
#
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.8.1)
#
# Requirement already satisfied, skipping upgrade: backcall in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.1.0)
#
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.7.4)
#
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.12.0)
#
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.3.9)
#
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.1.7)
#
# Requirement already satisfied, skipping upgrade: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from bleach->nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (1.0.1)
#
# Requirement already satisfied, skipping upgrade: parso>=0.2.0 in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from jedi>=0.10->ipython->jupyter-console->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.2.0)
#
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\ap18525\.conda\envs\environment\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->jupyter->jupyter-cjk-xelatex==0.2->-r C:\Users\ap18525\OneDrive - University of Bristol\AndresFrancesca\mat\Jupyter notebooks\iRONs\condaenv.f32ez9zo.requirements.txt (line 4)) (0.5.1)
#
# Installing collected packages: autopep8, hydroerr, hydrostats, jupyter-cjk-xelatex, pygame, seaborn, yapf
#
# Successfully installed autopep8-1.4.4 hydroerr-1.24 hydrostats-0.78 jupyter-cjk-xelatex-0.2 pygame-1.9.6 seaborn-0.9.0 yapf-0.28.0
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate environment
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# SafetyError: The package for platypus-opt located at C:\Program Files\Anaconda3\pkgs\platypus-opt-1.0.3-py_0
# appears to be corrupted. The path 'site-packages/platypus/algorithms.py'
# has an incorrect size.
#   reported size: 66274 bytes
#   actual size: 70387 bytes
#
# SafetyError: The package for platypus-opt located at C:\Program Files\Anaconda3\pkgs\platypus-opt-1.0.3-py_0
# appears to be corrupted. The path 'site-packages/platypus/operators.py'
# has an incorrect size.
#   reported size: 29748 bytes
#   actual size: 32379 bytes
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::hdf4-4.2.13-h712560f_2, anaconda::hdf5-1.10.2-hac2f561_1
#   path: 'library/copying'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::hdf4-4.2.13-h712560f_2, anaconda::hdf5-1.10.2-hac2f561_1
#   path: 'library/release.txt'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::console_shortcut-0.1.1-h6bb2dd7_3, anaconda::console_shortcut-0.1.1-h6bb2dd7_3
#   path: 'menu/console_shortcut.json'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::notebook-5.5.0-py36_0, anaconda::notebook-5.5.0-py36_0
#   path: 'menu/notebook.json'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::anaconda-navigator-1.9.7-py36_0, anaconda::anaconda-navigator-1.9.7-py36_0
#   path: 'menu/anaconda-navigator.json'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: anaconda::spyder-3.2.8-py36_0, anaconda::spyder-3.2.8-py36_0
#   path: 'menu/spyder_shortcut.json'

# %%
# !conda activate environment

# %%
from platypus
